# %%
# !unzip vae-npvc-master.zip
# !pip install pyworld
# !wget https://coe.northeastern.edu/Research/AClab/Speech%20Data/bea.zip
# Out:
# --2019-11-16 05:20:05--  https://coe.northeastern.edu/Research/AClab/Speech%20Data/bea.zip
# Resolving coe.northeastern.edu (coe.northeastern.edu)... 129.10.32.107
# Connecting to coe.northeastern.edu (coe.northeastern.edu)|129.10.32.107|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 952733720 (909M) [application/zip]
# Saving to: ‘bea.zip’
#
# bea.zip             100%[===================>] 908.60M  16.2MB/s    in 58s
#
# 2019-11-16 05:21:04 (15.6 MB/s) - ‘bea.zip’ saved [952733720/952733720]

# %%
# !unzip bea/neutral.zip
# Out:
# Archive:  bea/neutral.zip
#   inflating: neutral/neutral_113-140_0014.wav
#   inflating: neutral/neutral_113-140_0015.wav
#   inflating: neutral/neutral_113-140_0113.wav
#   inflating: neutral/neutral_113-140_0116.wav
#   inflating: neutral/neutral_113-140_0117.wav
#   inflating: neutral/neutral_113-140_0118.wav
#   inflating: neutral/neutral_113-140_0119.wav
#   inflating: neutral/neutral_113-140_0120.wav
#   inflating: neutral/neutral_113-140_0121.wav
#   inflating: neutral/neutral_113-140_0122.wav
#   inflating: neutral/neutral_113-140_0123.wav
#   inflating: neutral/neutral_113-140_0124.wav
#   inflating: neutral/neutral_113-140_0125.wav
#   inflating: neutral/neutral_113-140_0126.wav
#   inflating: neutral/neutral_113-140_0127.wav
#   inflating: neutral/neutral_113-140_0128.wav
#   inflating: neutral/neutral_113-140_0129.wav
#   inflating: neutral/neutral_113-140_0130.wav
#   inflating: neutral/neutral_113-140_0131.wav
#   inflating: neutral/neutral_113-140_0132.wav
# ...

# %%
import os
os.system('bash vae-npvc-master/download.sh')
# Out:
# 0

# %%
os.system('cp -r dataset vae-npvc-master')
# Out:
# 0

# %%
# %cd vae-npvc-master
# !ls
# Out:
# all_default.sh			  convert.py   main.py		 trainer
# analyzer.py			  dataset      model		 untitled
# architecture-vae-vcc2016.json	  download.sh  models.py	 util
# architecture-vawgan-vcc2016.json  etc	       README.md	 validate.py
# build.py			  LICENSE      requirements.txt

# %%
# !python3 analyzer.py
# import subprocess
# output=subprocess.getoutput('python3 vae-npvc-master/analyzer.py')
# print(output)
# Out:
# WARNING:tensorflow:From analyzer.py:18: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From analyzer.py:58: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From analyzer.py:59: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# ./dataset/vcc2016/wav/Training Set/TM2/100014.wav
# ./dataset/vcc2016/wav/Training Set/TM2/100036.wav
# ./dataset/vcc2016/wav/Training Set/TM2/100024.wav
# ./dataset/vcc2016/wav/Training Set/TM2/100145.wav
# ./dataset/vcc2016/wav/Training Set/TM2/100084.wav
# ./dataset/vcc2016/wav/Training Set/TM2/100121.wav
# ./dataset/vcc2016/wav/Training Set/TM2/100065.wav
# ./dataset/vcc2016/wav/Training Set/TM2/100038.wav
# ./dataset/vcc2016/wav/Training Set/TM2/100098.wav
# ./dataset/vcc2016/wav/Training Set/TM2/100011.wav
# ./dataset/vcc2016/wav/Training Set/TM2/100073.wav
# ./dataset/vcc2016/wav/Training Set/TM2/100146.wav
# ...

# %%
# !pip install soundfile
# !python3 build.py
# Out:
# ...
# WARNING:tensorflow:From /content/vae-npvc-master/analyzer.py:18: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From build.py:16: The name tf.gfile.MkDir is deprecated. Please use tf.io.gfile.mkdir instead.
#
# WARNING:tensorflow:From /content/vae-npvc-master/analyzer.py:143: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# 1458 files found
# WARNING:tensorflow:From /content/vae-npvc-master/analyzer.py:145: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# ...

# %%
# !python3 main.py --model ConvVAE --trainer VAETrainer --architecture architecture-vae-vcc2016.json
# Out:
# WARNING:tensorflow:From /content/vae-npvc-master/analyzer.py:18: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Using default logdir: logdir/train/1109-1209-11-2019
# WARNING:tensorflow:From main.py:49: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From /content/vae-npvc-master/analyzer.py:107: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:From /content/vae-npvc-master/analyzer.py:108: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# ...

# %%
# !python3 convert.py --src SF1 --trg TM3 --model ConvVAE --checkpoint logdir/train/1109-1209-11-2019/model.ckpt-55425 --file_pattern "./dataset/vcc2016/bin/Testing Set/{}/*.bin"
# Out:
# WARNING:tensorflow:From /content/vae-npvc-master/analyzer.py:18: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From convert.py:68: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# 54 files found
# WARNING:tensorflow:From /content/vae-npvc-master/analyzer.py:145: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:277: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...
